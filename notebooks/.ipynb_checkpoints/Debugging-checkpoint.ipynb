# %%
import pandas as pd
import numpy as np
from datetime import datetime

# pull in raw data file
file = '../data/data_final.csv'
transaction_df = pd.read_csv(file, engine='c',parse_dates={'transaction_datetime':[4,5]}, infer_datetime_format=True)

# %%
# creating customer table
customer_df = pd.DataFrame()

# Assigning existing values from data file
customer_df['customer_id'] = transaction_df['Customer ID']
customer_df['age'] = transaction_df['Age']
customer_df['gender'] = transaction_df['Gender'] # Gender not require
del customer_df['gender'] # Gender not required

# remove duplicates from customer_df
customer_df = customer_df.drop_duplicates(keep='first')

# change age to numeric
customer_df['age'] = pd.to_numeric(customer_df['age'])

# Fill NaNs with zeros
customer_df['age'] = customer_df['age'].fillna(value=0)

# Getting mean and SD of individuals aged >= 6 & <= 88
mean = customer_df["age"].ix[(customer_df["age"] >= 6) & (customer_df["age"] <= 88)].mean()
sd = customer_df["age"].ix[(customer_df["age"] >= 6) & (customer_df["age"] <= 88)].std()

# Replacing age 0 or > 88 with age generated as per normal distribution of mu and sd calculated above.
def assignAge(d):
    while(d < 6 or d > 88):
        d = np.random.normal(mean, sd, 1)[0]
    return int(d)

# Assigning age category.
def age_group(d):
    if d <= 18:
        return "YOUTH"
    elif d <= 35 and d > 18:
        return "ADULT"
    elif d <= 50 and d > 35:
        return "MIDDLE"
    else:
        return "SENIOR"

# Apply functions to 'age' column
customer_df['age'] = customer_df['age'].apply(assignAge)
customer_df['age_group'] = customer_df['age'].apply(age_group)

# merge customer and transaction,
merged_df = transaction_df.merge(customer_df, how="left",left_on="Customer ID", right_on='customer_id')

# %%
# REMOVE LATER
print(merged_df.columns)
print(len(merged_df.index))
# print(merged_df['transact_details_id'].nunique())
# Out:
# Index(['transaction_datetime', 'Customer ID', 'Age', 'Gender', 'Transact ID',
#        'Outlet', 'Outlet District', 'Transact Details ID', 'Item',
#        'Item Description', 'Quantity', 'Price', 'Spending', 'customer_id',
#        'age', 'age_group'],
#       dtype='object')
# 556580

# %%
# remove unecessary columns
del merged_df['Customer ID']
del merged_df['Age']
del merged_df['Gender']

# rename columns
merged_df = merged_df.rename(columns={'Transact ID':'transaction_id','Outlet':'outlet','Outlet District':'outlet_district',
                                      'Transact Details ID':'transact_details_id','Item':'item','Item Description':'item_desc',
                                      'Quantity':'qty','Price':'price','Spending':'spending'})

# Time of day function
def tod(d):
    today6am = datetime(12, 1, 1, 6, 0, 0).time()
    today12pm = datetime(12, 1, 1, 12, 0, 0).time()
    today6pm = datetime(12, 1, 1, 18, 0, 0).time()
    today12am = datetime(12, 1, 1, 23, 59, 59).time()

    if d.time() > today6am and d.time() < today12pm:  # greater than 6am and less than 12pm:
        return "BREAKFAST"
    elif d.time() >= today12pm and d.time() < today6pm:  # greater than 12pm and less than 6pm
        return "LUNCH"
    elif d.time() >= today6pm and d.time() <= today12am:
        return "DINNER"
    else:
        return "SUPPER"

# Apply time of day function, create new column
merged_df["time_of_day"] = merged_df["transaction_datetime"].apply(tod)

# Get derived items
derivedItems_df = pd.read_csv("../data/item_table_w_cost.csv")

# Rename derivedItems dataframe for consistency
derivedItems_df = derivedItems_df.rename(columns={'Item':'item','Item Description':'item_desc','Item Type':'item_type','Item Category':'item_cat',
                                                 'Price':'d_price'})
derivedItems_df['item'] = derivedItems_df['item'].str.strip()
merged_df['item'] = merged_df['item'].str.strip()
merged_df = pd.merge(merged_df,derivedItems_df, 'left', 'item')

# remove extra columns, cleaning things up
del merged_df['item_desc_y']

# rename item_desc_x column to item_desc
merged_df = merged_df.rename(columns={'item_desc_x':'item_desc'})

# drop rows with 'TAKEAWAY'
merged_df = merged_df[merged_df['item_type'] != "TAKEAWAY"]

# Replace 'Beverage' with 'drink
merged_df['item_type'] = merged_df['item_type'].replace('Beverage','Drink')

print(merged_df.groupby(['item_type']).size())

grouped_df = merged_df.groupby(['transaction_id','item_type']).size()

# Function to guess number of persons
def noPax(d):
    mains = d['Main']
    drinks = d['Drink']
    sides = d['Side']
    dessert = d['Dessert']
    soup = d["Soup"]
    # Number of mains shall be equal to the number of people.
    if mains > 0:
        return mains
    elif drinks > 0:
        return drinks
    elif sides > 0:
        return sides / 2
    elif soup > 0:
        return soup / 2
    elif dessert > 0:
        return dessert

output = {}
for transaction, subframe in grouped_df.groupby(level=0):
    temp_dict = subframe.to_dict()
    new_dict = {}
    for k1, k2 in temp_dict:
        val = temp_dict[(k1, k2)]
        new_dict[k2] = val

    if 'Main' not in new_dict:
        new_dict['Main'] = 0

    if 'Drink' not in new_dict:
        new_dict['Drink'] = 0

    if 'Side' not in new_dict:
        new_dict['Side'] = 0

    if 'Dessert' not in new_dict:
        new_dict['Dessert'] = 0

    if 'Soup' not in new_dict:
        new_dict['Soup'] = 0

    numPax = noPax(new_dict)
    numPax = np.ceil(numPax)
    if numPax < 1: numPax = 1
    output[transaction] = numPax

# Create numpax_df
numpax_df = pd.DataFrame(list(output.items()))
# Rename columns for readability
numpax_df  = numpax_df.rename(columns={0:'transaction_id',1:'numpax'})

# Set variable type as int, to be safe
numpax_df['transaction_id'] = numpax_df['transaction_id'].astype(int)
numpax_df['numpax'] = numpax_df['numpax'].astype(int)

# Function for getting groupCategory
def groupCategory(d):
    if d >= 3:
        return "GROUP"
    elif d == 2:
        return "COUPLE"
    else:
        return "SOLO"

# Apply group category function
numpax_df['group_category'] = numpax_df['numpax'].apply(groupCategory)

merged_df = pd.merge(merged_df, numpax_df, how='left', left_on='transaction_id', right_on='transaction_id')
# Out:
# item_type
# Dessert     27523
# Drink      180286
# Main       191887
# Side       133959
# dtype: int64

# %%
# REMOVE LATER
print(merged_df.columns)
print(len(merged_df.index))
print(merged_df['transact_details_id'].nunique())
# Out:
# Index(['transaction_datetime', 'transaction_id', 'outlet', 'outlet_district',
#        'transact_details_id', 'item', 'item_desc', 'qty', 'price', 'spending',
#        'customer_id', 'age', 'age_group', 'time_of_day', 'item_type',
#        'item_cat', 'd_price', 'numpax', 'group_category'],
#       dtype='object')
# 556580
# 556580

# %%
# REMOVED LATER
test_grp = derivedItems_df.groupby(['item_desc']).size().reset_index()
test_grp.sort_values(0,ascending=False)
# Out:
#                               item_desc  0
# 0            AlmondCream Glutinous Ball  1
# 105                     Paoched Lettuce  1
# 98                        Mango SnowIce  1
# 99                             Milk Tea  1
# 100                                Milo  1
# 101        Minced Kai Lan W Silver Fish  1
# 102                        Mush Bk Rice  1
# 103                 Mushroom Cream Spag  1
# 104                  Pan Fried Dumpling  1
# 106                   Peach Ice-blended  1
# 115                      RAINBOW SPRITE  1
# 107      Peanut Butter Milk Thick Toast  1
# 108                  Pork Chop Bee Hoon  1
# 109                   Pork Chop Bk Rice  1
# 110                 Pork Chop Frag Rice  1
# 111                    Pork Chop Noodle  1
# 112           Pork N Century Egg Congee  1
# 113                 Prawn Paste Chicken  1
# 97                         Mango Pomelo  1
# 96                   Lychee Ice-blended  1
# 95                 LuncheonMeatSoup Ndl  1
# 94              Luncheon N Egg Sandwich  1
# 79                 Iced Honey Green Tea  1
# 80                       Iced Lemon Tea  1
# 81                      Iced Lychee Tea  1
# 82                        Iced Milk Tea  1
# 83                  Iced Milk Tea Float  1
# 84                       Iced Peach Tea  1
# 85                        Iced Soy Milk  1
# 86                        Iced Yuzu Tea  1
# ..                                  ... ..
# 65            HONEY CHICKEN WING (5pcs)  1
# 66                   Ham & Egg Soup Ndl  1
# 67         Ham Egg Toast N French Fries  1
# 68                              Har Gao  1
# 69              Home-Made Cold Beancurd  1
# 70               Homemade Cold Beancurd  1
# 71                       Hot Coffee-Tea  1
# 72                  Hot Honey Green Tea  1
# 73                 Hot Honey with Lemon  1
# 74                      ICED MILO FLOAT  1
# 59                    Fresh  Lime Juice  1
# 57                       Fish Slice Por  1
# 40                   Coke Float (Promo)  1
# 56                    Fish Slice Muifan  1
# 41                    Cold / Iced Water  1
# 42                          Custard Bun  1
# 43              Deep Fried Prawn (3pcs)  1
# 44   Deep-fried Prawns with Mango sauce  1
# 45                Diced Pork Fried Rice  1
# 46                   Egg & Ham Sandwich  1
# 47        F'mented Pork Dry Curry Ramen  1
# 48                   F.Fries Curry Mayo  1
# 49                F.Toast Chicken Floss  1
# 50                    F.Toast Ice Cream  1
# 51            Fermented Pork Dry Noodle  1
# 52                         Fish & Chips  1
# 53                         Fish Bk Rice  1
# 54                     Fish Fillet Spag  1
# 55             Fish Papaya Soup Beehoon  1
# 153                            Yuzu Tea  1
#
# [154 rows x 2 columns]

# %%
# Create new dataframe of total quantity of items ordered for each age_group, tod, numpax profile
profile_item_total_df =  merged_df.groupby(['age_group','time_of_day','group_category'])['qty'].sum().reset_index()
item_total_df = merged_df.groupby(['age_group','time_of_day','group_category','item_desc','item_type', 'item_cat','d_price'])\
    .size().reset_index().rename(columns={0:'item_total'})

item_total_df = item_total_df.rename(columns={'d_price':'price'})
# Out:
# Index(['age_group', 'time_of_day', 'group_category', 'qty'], dtype='object')
# Index(['age_group', 'time_of_day', 'group_category', 'item_desc', 'item_type',
#        'item_cat', 'd_price', 'item_total'],
#       dtype='object')

# %%
# Merge the two tables together
profile_and_item_total_df = pd.merge(profile_item_total_df,item_total_df,how='left',on=['age_group','time_of_day','group_category'])

temp_df = profile_and_item_total_df.ix[(profile_and_item_total_df.age_group == 'ADULT') &
                                       (profile_and_item_total_df.time_of_day == 'BREAKFAST') &
                                       (profile_and_item_total_df.group_category == 'COUPLE')]
# Out:
# 150
# 150

# %%
# Calculate utility scores
profile_and_item_total_df['uscore'] = (profile_and_item_total_df['item_total'] / profile_and_item_total_df['qty']) * 10000

# Modify Utility Scores, If main +25%, if Drink -50%
main_mask = (profile_and_item_total_df['item_type'] == 'Main')
main_valid = profile_and_item_total_df[main_mask]
profile_and_item_total_df.loc[main_mask,'uscore'] = main_valid['uscore'] * 1.25

drink_mask = (profile_and_item_total_df['item_type'] == 'Drink')
drink_valid = profile_and_item_total_df[drink_mask]
profile_and_item_total_df.loc[drink_mask,'uscore'] = drink_valid['uscore'] * 0.5

# Round utility scores to nearest integer and set to type int
profile_and_item_total_df['uscore'] = profile_and_item_total_df['uscore'].round()
profile_and_item_total_df['uscore'] = profile_and_item_total_df['uscore'].astype(int)

# Change price to cents and set to type int
profile_and_item_total_df['price'] = profile_and_item_total_df['price'].apply(lambda x: x * 100)
profile_and_item_total_df['price'] = profile_and_item_total_df['price'].astype(int)

# Remove unwanted columns, again
# del profile_and_item_total_df['group_category_y']
# profile_and_item_total_df = profile_and_item_total_df.rename(columns={'group_category_x':'group_category'})

# Output DataFrame
output_df = pd.DataFrame()
output_df['age_group'] = profile_and_item_total_df['age_group']
output_df['time_of_day'] = profile_and_item_total_df['time_of_day']
output_df['group_category'] = profile_and_item_total_df['group_category']
output_df['uscore'] = profile_and_item_total_df['uscore']
output_df['price'] = profile_and_item_total_df['price']
output_df['item_type'] = profile_and_item_total_df['item_type']
output_df['item_cat'] = profile_and_item_total_df['item_cat']
output_df['item_desc'] = profile_and_item_total_df['item_desc']

# print(output_df.head())

# output_group_df = output_df.groupby(['age_group','time_of_day','group_category']).size().groupby(level=0)

# loop through each sub category and generate csvs
age_group_list = output_df['age_group'].unique().tolist()
tod_list = output_df['time_of_day'].unique().tolist()
grp_cat_list = output_df['group_category'].unique().tolist()

# %%
soup_mask = (output_df['item_desc'].str.contains(r"^Soup"))
soup_valid = output_df[soup_mask]
output_df.loc(soup_mask,'')

# %%
output_df[output_df['item_cat'].str.contains(r"^Soup;")]
# Out:
#      age_group time_of_day group_category  uscore  price item_type  \
# 12       ADULT   BREAKFAST         COUPLE      36    594      Side
# 26       ADULT   BREAKFAST         COUPLE      58    909      Main
# 127      ADULT   BREAKFAST         COUPLE      39   1030      Main
# 143      ADULT   BREAKFAST         COUPLE      41    715      Side
# 163      ADULT   BREAKFAST          GROUP      27    594      Side
# 175      ADULT   BREAKFAST          GROUP     154    909      Main
# 263      ADULT   BREAKFAST          GROUP      51   1030      Main
# 277      ADULT   BREAKFAST          GROUP      27    715      Side
# 296      ADULT   BREAKFAST           SOLO      23    594      Side
# 311      ADULT   BREAKFAST           SOLO      74    909      Main
# 416      ADULT   BREAKFAST           SOLO      45   1030      Main
# 434      ADULT   BREAKFAST           SOLO      49    715      Side
# 456      ADULT      DINNER         COUPLE      28    594      Side
# 473      ADULT      DINNER         COUPLE      29    909      Main
# 584      ADULT      DINNER         COUPLE      21   1030      Main
# 602      ADULT      DINNER         COUPLE      31    715      Side
# 624      ADULT      DINNER          GROUP      20    594      Side
# 641      ADULT      DINNER          GROUP      27    909      Main
# 752      ADULT      DINNER          GROUP      27   1030      Main
# 770      ADULT      DINNER          GROUP      17    715      Side
# 792      ADULT      DINNER           SOLO      38    594      Side
# 809      ADULT      DINNER           SOLO      21    909      Main
# 920      ADULT      DINNER           SOLO      15   1030      Main
# 938      ADULT      DINNER           SOLO      56    715      Side
# 960      ADULT       LUNCH         COUPLE      23    594      Side
# 977      ADULT       LUNCH         COUPLE      33    909      Main
# 1088     ADULT       LUNCH         COUPLE      26   1030      Main
# 1106     ADULT       LUNCH         COUPLE      30    715      Side
# 1128     ADULT       LUNCH          GROUP       8    594      Side
# 1145     ADULT       LUNCH          GROUP      26    909      Main
# ...        ...         ...            ...     ...    ...       ...
# 5843     YOUTH   BREAKFAST           SOLO      55    715      Side
# 5862     YOUTH      DINNER         COUPLE      19    594      Side
# 5879     YOUTH      DINNER         COUPLE      39    909      Main
# 5989     YOUTH      DINNER         COUPLE      28   1030      Main
# 6006     YOUTH      DINNER         COUPLE      25    715      Side
# 6028     YOUTH      DINNER          GROUP      11    594      Side
# 6045     YOUTH      DINNER          GROUP      10    909      Main
# 6156     YOUTH      DINNER          GROUP       7   1030      Main
# 6174     YOUTH      DINNER          GROUP      29    715      Side
# 6196     YOUTH      DINNER           SOLO      33    594      Side
# 6213     YOUTH      DINNER           SOLO       8    909      Main
# 6323     YOUTH      DINNER           SOLO      11   1030      Main
# 6341     YOUTH      DINNER           SOLO      36    715      Side
# 6363     YOUTH       LUNCH         COUPLE       8    594      Side
# 6380     YOUTH       LUNCH         COUPLE      37    909      Main
# 6489     YOUTH       LUNCH         COUPLE      16   1030      Main
# 6507     YOUTH       LUNCH         COUPLE      25    715      Side
# 6529     YOUTH       LUNCH          GROUP      17    594      Side
# 6546     YOUTH       LUNCH          GROUP      27    909      Main
# 6655     YOUTH       LUNCH          GROUP      27   1030      Main
# 6673     YOUTH       LUNCH          GROUP      22    715      Side
# 6695     YOUTH       LUNCH           SOLO      26    594      Side
# 6712     YOUTH       LUNCH           SOLO       4    909      Main
# 6822     YOUTH       LUNCH           SOLO       4   1030      Main
# 6839     YOUTH       LUNCH           SOLO      46    715      Side
# 6853     YOUTH      SUPPER         COUPLE     190    594      Side
# 6915     YOUTH      SUPPER         COUPLE      63    715      Side
# 6928     YOUTH      SUPPER          GROUP     221    594      Side
# 6987     YOUTH      SUPPER          GROUP      74    715      Side
# 7000     YOUTH      SUPPER           SOLO      46    594      Side
#
#                item_cat                             item_desc
# 12            Soup;Beef                           Borsch Soup
# 26         Soup;Chicken                 Chicken Macaroni Soup
# 127   Soup;Seafood;Pork  Seafood and Slice Pork Macaroni Soup
# 143   Soup;Pork;Seafood                           Wanton Soup
# 163           Soup;Beef                           Borsch Soup
# 175        Soup;Chicken                 Chicken Macaroni Soup
# 263   Soup;Seafood;Pork  Seafood and Slice Pork Macaroni Soup
# 277   Soup;Pork;Seafood                           Wanton Soup
# 296           Soup;Beef                           Borsch Soup
# 311        Soup;Chicken                 Chicken Macaroni Soup
# 416   Soup;Seafood;Pork  Seafood and Slice Pork Macaroni Soup
# 434   Soup;Pork;Seafood                           Wanton Soup
# 456           Soup;Beef                           Borsch Soup
# 473        Soup;Chicken                 Chicken Macaroni Soup
# 584   Soup;Seafood;Pork  Seafood and Slice Pork Macaroni Soup
# 602   Soup;Pork;Seafood                           Wanton Soup
# 624           Soup;Beef                           Borsch Soup
# 641        Soup;Chicken                 Chicken Macaroni Soup
# 752   Soup;Seafood;Pork  Seafood and Slice Pork Macaroni Soup
# 770   Soup;Pork;Seafood                           Wanton Soup
# 792           Soup;Beef                           Borsch Soup
# 809        Soup;Chicken                 Chicken Macaroni Soup
# 920   Soup;Seafood;Pork  Seafood and Slice Pork Macaroni Soup
# 938   Soup;Pork;Seafood                           Wanton Soup
# 960           Soup;Beef                           Borsch Soup
# 977        Soup;Chicken                 Chicken Macaroni Soup
# 1088  Soup;Seafood;Pork  Seafood and Slice Pork Macaroni Soup
# 1106  Soup;Pork;Seafood                           Wanton Soup
# 1128          Soup;Beef                           Borsch Soup
# 1145       Soup;Chicken                 Chicken Macaroni Soup
# ...                 ...                                   ...
# 5843  Soup;Pork;Seafood                           Wanton Soup
# 5862          Soup;Beef                           Borsch Soup
# 5879       Soup;Chicken                 Chicken Macaroni Soup
# 5989  Soup;Seafood;Pork  Seafood and Slice Pork Macaroni Soup
# 6006  Soup;Pork;Seafood                           Wanton Soup
# 6028          Soup;Beef                           Borsch Soup
# 6045       Soup;Chicken                 Chicken Macaroni Soup
# 6156  Soup;Seafood;Pork  Seafood and Slice Pork Macaroni Soup
# 6174  Soup;Pork;Seafood                           Wanton Soup
# 6196          Soup;Beef                           Borsch Soup
# 6213       Soup;Chicken                 Chicken Macaroni Soup
# 6323  Soup;Seafood;Pork  Seafood and Slice Pork Macaroni Soup
# 6341  Soup;Pork;Seafood                           Wanton Soup
# 6363          Soup;Beef                           Borsch Soup
# 6380       Soup;Chicken                 Chicken Macaroni Soup
# 6489  Soup;Seafood;Pork  Seafood and Slice Pork Macaroni Soup
# 6507  Soup;Pork;Seafood                           Wanton Soup
# 6529          Soup;Beef                           Borsch Soup
# 6546       Soup;Chicken                 Chicken Macaroni Soup
# 6655  Soup;Seafood;Pork  Seafood and Slice Pork Macaroni Soup
# 6673  Soup;Pork;Seafood                           Wanton Soup
# 6695          Soup;Beef                           Borsch Soup
# 6712       Soup;Chicken                 Chicken Macaroni Soup
# 6822  Soup;Seafood;Pork  Seafood and Slice Pork Macaroni Soup
# 6839  Soup;Pork;Seafood                           Wanton Soup
# 6853          Soup;Beef                           Borsch Soup
# 6915  Soup;Pork;Seafood                           Wanton Soup
# 6928          Soup;Beef                           Borsch Soup
# 6987  Soup;Pork;Seafood                           Wanton Soup
# 7000          Soup;Beef                           Borsch Soup
#
# [165 rows x 8 columns]

# %%
output_df[output_df['item_cat'].str.contains(r"^Noodlesoup;")]
# Out:
#      age_group time_of_day group_category  uscore  price item_type  \
# 13       ADULT   BREAKFAST         COUPLE      39   1188      Main
# 27       ADULT   BREAKFAST         COUPLE      84   1394      Main
# 55       ADULT   BREAKFAST         COUPLE      52   1394      Main
# 65       ADULT   BREAKFAST         COUPLE     104    944      Main
# 93       ADULT   BREAKFAST         COUPLE      78   1067      Main
# 138      ADULT   BREAKFAST         COUPLE      52    944      Main
# 164      ADULT   BREAKFAST          GROUP      17   1188      Main
# 176      ADULT   BREAKFAST          GROUP      17   1394      Main
# 198      ADULT   BREAKFAST          GROUP      68   1394      Main
# 206      ADULT   BREAKFAST          GROUP     103    944      Main
# 230      ADULT   BREAKFAST          GROUP      86   1067      Main
# 297      ADULT   BREAKFAST           SOLO      29   1188      Main
# 312      ADULT   BREAKFAST           SOLO      53   1394      Main
# 342      ADULT   BREAKFAST           SOLO      33   1394      Main
# 353      ADULT   BREAKFAST           SOLO      86    944      Main
# 382      ADULT   BREAKFAST           SOLO      53   1067      Main
# 428      ADULT   BREAKFAST           SOLO      49    944      Main
# 457      ADULT      DINNER         COUPLE      71   1188      Main
# 474      ADULT      DINNER         COUPLE     103   1394      Main
# 505      ADULT      DINNER         COUPLE      87   1394      Main
# 516      ADULT      DINNER         COUPLE      45    944      Main
# 546      ADULT      DINNER         COUPLE      61   1067      Main
# 596      ADULT      DINNER         COUPLE      36    944      Main
# 625      ADULT      DINNER          GROUP      81   1188      Main
# 642      ADULT      DINNER          GROUP      91   1394      Main
# 673      ADULT      DINNER          GROUP     102   1394      Main
# 684      ADULT      DINNER          GROUP      65    944      Main
# 714      ADULT      DINNER          GROUP      56   1067      Main
# 764      ADULT      DINNER          GROUP      32    944      Main
# 793      ADULT      DINNER           SOLO      46   1188      Main
# ...        ...         ...            ...     ...    ...       ...
# 6244     YOUTH      DINNER           SOLO      42   1394      Main
# 6255     YOUTH      DINNER           SOLO      64    944      Main
# 6285     YOUTH      DINNER           SOLO      60   1067      Main
# 6335     YOUTH      DINNER           SOLO      34    944      Main
# 6364     YOUTH       LUNCH         COUPLE      90   1188      Main
# 6381     YOUTH       LUNCH         COUPLE      42   1394      Main
# 6412     YOUTH       LUNCH         COUPLE      63   1394      Main
# 6423     YOUTH       LUNCH         COUPLE      90    944      Main
# 6451     YOUTH       LUNCH         COUPLE      79   1067      Main
# 6501     YOUTH       LUNCH         COUPLE      42    944      Main
# 6530     YOUTH       LUNCH          GROUP      87   1188      Main
# 6547     YOUTH       LUNCH          GROUP      49   1394      Main
# 6578     YOUTH       LUNCH          GROUP      49   1394      Main
# 6589     YOUTH       LUNCH          GROUP     124    944      Main
# 6619     YOUTH       LUNCH          GROUP      92   1067      Main
# 6667     YOUTH       LUNCH          GROUP      11    944      Main
# 6696     YOUTH       LUNCH           SOLO      78   1188      Main
# 6713     YOUTH       LUNCH           SOLO      17   1394      Main
# 6743     YOUTH       LUNCH           SOLO      45   1394      Main
# 6754     YOUTH       LUNCH           SOLO      50    944      Main
# 6784     YOUTH       LUNCH           SOLO      62   1067      Main
# 6833     YOUTH       LUNCH           SOLO       8    944      Main
# 6854     YOUTH      SUPPER         COUPLE      79   1188      Main
# 6871     YOUTH      SUPPER         COUPLE      79    944      Main
# 6888     YOUTH      SUPPER         COUPLE      79   1067      Main
# 6912     YOUTH      SUPPER         COUPLE      79    944      Main
# 6929     YOUTH      SUPPER          GROUP     184   1188      Main
# 7001     YOUTH      SUPPER           SOLO      58   1188      Main
# 7025     YOUTH      SUPPER           SOLO     115    944      Main
# 7074     YOUTH      SUPPER           SOLO     115    944      Main
#
#                 item_cat                          item_desc
# 13       Noodlesoup;Beef  Braised Beef Brisket Soup Noodles
# 27    Noodlesoup;Chicken        Chicken Papaya Soup Beehoon
# 55       Noodlesoup;Fish           Fish Papaya Soup Beehoon
# 65       Noodlesoup;Pork                 Ham & Egg Soup Ndl
# 93       Noodlesoup;Pork               LuncheonMeatSoup Ndl
# 138      Noodlesoup;Pork               Spy P.Dices Soup Ndl
# 164      Noodlesoup;Beef  Braised Beef Brisket Soup Noodles
# 176   Noodlesoup;Chicken        Chicken Papaya Soup Beehoon
# 198      Noodlesoup;Fish           Fish Papaya Soup Beehoon
# 206      Noodlesoup;Pork                 Ham & Egg Soup Ndl
# 230      Noodlesoup;Pork               LuncheonMeatSoup Ndl
# 297      Noodlesoup;Beef  Braised Beef Brisket Soup Noodles
# 312   Noodlesoup;Chicken        Chicken Papaya Soup Beehoon
# 342      Noodlesoup;Fish           Fish Papaya Soup Beehoon
# 353      Noodlesoup;Pork                 Ham & Egg Soup Ndl
# 382      Noodlesoup;Pork               LuncheonMeatSoup Ndl
# 428      Noodlesoup;Pork               Spy P.Dices Soup Ndl
# 457      Noodlesoup;Beef  Braised Beef Brisket Soup Noodles
# 474   Noodlesoup;Chicken        Chicken Papaya Soup Beehoon
# 505      Noodlesoup;Fish           Fish Papaya Soup Beehoon
# 516      Noodlesoup;Pork                 Ham & Egg Soup Ndl
# 546      Noodlesoup;Pork               LuncheonMeatSoup Ndl
# 596      Noodlesoup;Pork               Spy P.Dices Soup Ndl
# 625      Noodlesoup;Beef  Braised Beef Brisket Soup Noodles
# 642   Noodlesoup;Chicken        Chicken Papaya Soup Beehoon
# 673      Noodlesoup;Fish           Fish Papaya Soup Beehoon
# 684      Noodlesoup;Pork                 Ham & Egg Soup Ndl
# 714      Noodlesoup;Pork               LuncheonMeatSoup Ndl
# 764      Noodlesoup;Pork               Spy P.Dices Soup Ndl
# 793      Noodlesoup;Beef  Braised Beef Brisket Soup Noodles
# ...                  ...                                ...
# 6244     Noodlesoup;Fish           Fish Papaya Soup Beehoon
# 6255     Noodlesoup;Pork                 Ham & Egg Soup Ndl
# 6285     Noodlesoup;Pork               LuncheonMeatSoup Ndl
# 6335     Noodlesoup;Pork               Spy P.Dices Soup Ndl
# 6364     Noodlesoup;Beef  Braised Beef Brisket Soup Noodles
# 6381  Noodlesoup;Chicken        Chicken Papaya Soup Beehoon
# 6412     Noodlesoup;Fish           Fish Papaya Soup Beehoon
# 6423     Noodlesoup;Pork                 Ham & Egg Soup Ndl
# 6451     Noodlesoup;Pork               LuncheonMeatSoup Ndl
# 6501     Noodlesoup;Pork               Spy P.Dices Soup Ndl
# 6530     Noodlesoup;Beef  Braised Beef Brisket Soup Noodles
# 6547  Noodlesoup;Chicken        Chicken Papaya Soup Beehoon
# 6578     Noodlesoup;Fish           Fish Papaya Soup Beehoon
# 6589     Noodlesoup;Pork                 Ham & Egg Soup Ndl
# 6619     Noodlesoup;Pork               LuncheonMeatSoup Ndl
# 6667     Noodlesoup;Pork               Spy P.Dices Soup Ndl
# 6696     Noodlesoup;Beef  Braised Beef Brisket Soup Noodles
# 6713  Noodlesoup;Chicken        Chicken Papaya Soup Beehoon
# 6743     Noodlesoup;Fish           Fish Papaya Soup Beehoon
# 6754     Noodlesoup;Pork                 Ham & Egg Soup Ndl
# 6784     Noodlesoup;Pork               LuncheonMeatSoup Ndl
# 6833     Noodlesoup;Pork               Spy P.Dices Soup Ndl
# 6854     Noodlesoup;Beef  Braised Beef Brisket Soup Noodles
# 6871     Noodlesoup;Pork                 Ham & Egg Soup Ndl
# 6888     Noodlesoup;Pork               LuncheonMeatSoup Ndl
# 6912     Noodlesoup;Pork               Spy P.Dices Soup Ndl
# 6929     Noodlesoup;Beef  Braised Beef Brisket Soup Noodles
# 7001     Noodlesoup;Beef  Braised Beef Brisket Soup Noodles
# 7025     Noodlesoup;Pork                 Ham & Egg Soup Ndl
# 7074     Noodlesoup;Pork               Spy P.Dices Soup Ndl
#
# [260 rows x 8 columns]

# %%
output_df[output_df['item_cat'].str.contains(r"^Porridge;")]
# Out:
#      age_group time_of_day group_category  uscore  price item_type  \
# 17       ADULT   BREAKFAST         COUPLE     149   1030      Main
# 57       ADULT   BREAKFAST         COUPLE      84   1030      Main
# 107      ADULT   BREAKFAST         COUPLE      13   1030      Main
# 109      ADULT   BREAKFAST         COUPLE      26   1030      Main
# 122      ADULT   BREAKFAST         COUPLE      26   1151      Main
# 132      ADULT   BREAKFAST         COUPLE     214   1200      Main
# 136      ADULT   BREAKFAST         COUPLE      32   1030      Main
# 168      ADULT   BREAKFAST          GROUP     154   1030      Main
# 199      ADULT   BREAKFAST          GROUP     188   1030      Main
# 259      ADULT   BREAKFAST          GROUP      17   1151      Main
# 268      ADULT   BREAKFAST          GROUP      86   1200      Main
# 302      ADULT   BREAKFAST           SOLO     106   1030      Main
# 344      ADULT   BREAKFAST           SOLO     106   1030      Main
# 397      ADULT   BREAKFAST           SOLO      29   1030      Main
# 399      ADULT   BREAKFAST           SOLO      49   1030      Main
# 412      ADULT   BREAKFAST           SOLO      16   1151      Main
# 421      ADULT   BREAKFAST           SOLO     106   1200      Main
# 425      ADULT   BREAKFAST           SOLO      41   1030      Main
# 463      ADULT      DINNER         COUPLE      68   1030      Main
# 507      ADULT      DINNER         COUPLE      48   1030      Main
# 563      ADULT      DINNER         COUPLE      20   1030      Main
# 565      ADULT      DINNER         COUPLE      12   1030      Main
# 579      ADULT      DINNER         COUPLE      23   1151      Main
# 589      ADULT      DINNER         COUPLE     107   1200      Main
# 593      ADULT      DINNER         COUPLE      25   1030      Main
# 631      ADULT      DINNER          GROUP      69   1030      Main
# 675      ADULT      DINNER          GROUP      59   1030      Main
# 731      ADULT      DINNER          GROUP      22   1030      Main
# 733      ADULT      DINNER          GROUP      10   1030      Main
# 747      ADULT      DINNER          GROUP      25   1151      Main
# ...        ...         ...            ...     ...    ...       ...
# 6302     YOUTH      DINNER           SOLO      57   1030      Main
# 6304     YOUTH      DINNER           SOLO       4   1030      Main
# 6318     YOUTH      DINNER           SOLO      26   1151      Main
# 6328     YOUTH      DINNER           SOLO     102   1200      Main
# 6332     YOUTH      DINNER           SOLO      26   1030      Main
# 6370     YOUTH       LUNCH         COUPLE      69   1030      Main
# 6414     YOUTH       LUNCH         COUPLE      85   1030      Main
# 6468     YOUTH       LUNCH         COUPLE      11   1030      Main
# 6470     YOUTH       LUNCH         COUPLE      16   1030      Main
# 6484     YOUTH       LUNCH         COUPLE      26   1151      Main
# 6494     YOUTH       LUNCH         COUPLE     100   1200      Main
# 6498     YOUTH       LUNCH         COUPLE      11   1030      Main
# 6536     YOUTH       LUNCH          GROUP      87   1030      Main
# 6580     YOUTH       LUNCH          GROUP     124   1030      Main
# 6635     YOUTH       LUNCH          GROUP      27   1030      Main
# 6650     YOUTH       LUNCH          GROUP      32   1151      Main
# 6660     YOUTH       LUNCH          GROUP      65   1200      Main
# 6664     YOUTH       LUNCH          GROUP      11   1030      Main
# 6702     YOUTH       LUNCH           SOLO      41   1030      Main
# 6745     YOUTH       LUNCH           SOLO      33   1030      Main
# 6801     YOUTH       LUNCH           SOLO      25   1030      Main
# 6803     YOUTH       LUNCH           SOLO       4   1030      Main
# 6817     YOUTH       LUNCH           SOLO       8   1151      Main
# 6827     YOUTH       LUNCH           SOLO      62   1200      Main
# 6830     YOUTH       LUNCH           SOLO      21   1030      Main
# 6869     YOUTH      SUPPER         COUPLE      79   1030      Main
# 6898     YOUTH      SUPPER         COUPLE      79   1030      Main
# 6931     YOUTH      SUPPER          GROUP     184   1030      Main
# 7004     YOUTH      SUPPER           SOLO      58   1030      Main
# 7070     YOUTH      SUPPER           SOLO      58   1200      Main
#
#               item_cat                  item_desc
# 17       Porridge;Pork          Cent Egg Pork Por
# 57       Porridge;Fish             Fish Slice Por
# 107      Porridge;Pork  Pork N Century Egg Congee
# 109      Porridge;Pork  Pork n Century Egg Congee
# 122   Porridge;Seafood              Sampan Congee
# 132   Porridge;Seafood      Sliced Empress Congee
# 136      Porridge;Pork             Spicy Pork Por
# 168      Porridge;Pork          Cent Egg Pork Por
# 199      Porridge;Fish             Fish Slice Por
# 259   Porridge;Seafood              Sampan Congee
# 268   Porridge;Seafood      Sliced Empress Congee
# 302      Porridge;Pork          Cent Egg Pork Por
# 344      Porridge;Fish             Fish Slice Por
# 397      Porridge;Pork  Pork N Century Egg Congee
# 399      Porridge;Pork  Pork n Century Egg Congee
# 412   Porridge;Seafood              Sampan Congee
# 421   Porridge;Seafood      Sliced Empress Congee
# 425      Porridge;Pork             Spicy Pork Por
# 463      Porridge;Pork          Cent Egg Pork Por
# 507      Porridge;Fish             Fish Slice Por
# 563      Porridge;Pork  Pork N Century Egg Congee
# 565      Porridge;Pork  Pork n Century Egg Congee
# 579   Porridge;Seafood              Sampan Congee
# 589   Porridge;Seafood      Sliced Empress Congee
# 593      Porridge;Pork             Spicy Pork Por
# 631      Porridge;Pork          Cent Egg Pork Por
# 675      Porridge;Fish             Fish Slice Por
# 731      Porridge;Pork  Pork N Century Egg Congee
# 733      Porridge;Pork  Pork n Century Egg Congee
# 747   Porridge;Seafood              Sampan Congee
# ...                ...                        ...
# 6302     Porridge;Pork  Pork N Century Egg Congee
# 6304     Porridge;Pork  Pork n Century Egg Congee
# 6318  Porridge;Seafood              Sampan Congee
# 6328  Porridge;Seafood      Sliced Empress Congee
# 6332     Porridge;Pork             Spicy Pork Por
# 6370     Porridge;Pork          Cent Egg Pork Por
# 6414     Porridge;Fish             Fish Slice Por
# 6468     Porridge;Pork  Pork N Century Egg Congee
# 6470     Porridge;Pork  Pork n Century Egg Congee
# 6484  Porridge;Seafood              Sampan Congee
# 6494  Porridge;Seafood      Sliced Empress Congee
# 6498     Porridge;Pork             Spicy Pork Por
# 6536     Porridge;Pork          Cent Egg Pork Por
# 6580     Porridge;Fish             Fish Slice Por
# 6635     Porridge;Pork  Pork N Century Egg Congee
# 6650  Porridge;Seafood              Sampan Congee
# 6660  Porridge;Seafood      Sliced Empress Congee
# 6664     Porridge;Pork             Spicy Pork Por
# 6702     Porridge;Pork          Cent Egg Pork Por
# 6745     Porridge;Fish             Fish Slice Por
# 6801     Porridge;Pork  Pork N Century Egg Congee
# 6803     Porridge;Pork  Pork n Century Egg Congee
# 6817  Porridge;Seafood              Sampan Congee
# 6827  Porridge;Seafood      Sliced Empress Congee
# 6830     Porridge;Pork             Spicy Pork Por
# 6869     Porridge;Fish             Fish Slice Por
# 6898     Porridge;Pork  Pork N Century Egg Congee
# 6931     Porridge;Pork          Cent Egg Pork Por
# 7004     Porridge;Pork          Cent Egg Pork Por
# 7070  Porridge;Seafood      Sliced Empress Congee
#
# [295 rows x 8 columns]

# %%
output_df[output_df['item_cat'].str.contains(r"^Drink;Hot")]

# %%
outputpath = '../data/output/'
for ag in age_group_list:
    for tod in tod_list:
        for grp_cat in grp_cat_list:
            temp_df = output_df.ix[(output_df.age_group == ag) &
                                      (output_df.time_of_day == tod) &
                                      (output_df.group_category == grp_cat)]

            file_name = str(ag)+"_"+str(tod)+"_"+str(grp_cat)
            temp_df.ix[:,'uscore':'item_desc'].to_csv(outputpath+file_name+".csv",header=False, index=False)
